# %% [markdown]
# # How to Use Deep Reinforcement Learning to Improve your Supply Chain
#
# Full write up available [here](https://www.datahubbs.com/how-to-use-deep-reinforcement-learning-to-improve-your-supply-chain/).
#
# Note Ray is not a dependency of OR-Gym. We want OR-Gym to be able to stand independently of other RL libraries as much as possible.
#
# There have been breaking changes that have been introduced in later version of Ray which affect this environment in particular. To ensure no conflicts, please run:
# - `pip install ray==1.0.0`
# - `pip install ray[rllib]`
# - `pip install ray[tune]`
# - `pip install tensorflow==2.3.0`

# %%
import or_gym
from or_gym.utils import create_env
import ray
from ray.rllib.agents.ppo import PPOTrainer
from ray import tune
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec

# %%
def register_env(env_name, env_config={}):
    env = create_env(env_name)
    tune.register_env(env_name, 
        lambda env_name: env(env_name,
            env_config=env_config))

# Environment and RL Configuration Settings
env_name = 'InvManagement-v1'
# env_name = "Knapsack-v0"
env_config = {} # Change environment parameters here
rl_config = dict(
    framework= "torch",
    env=env_name,
    num_workers=2,
    env_config=env_config,
    model=dict(
        vf_share_layers=False,
        fcnet_activation='elu',
        fcnet_hiddens=[256, 256]
    ),
    lr=1e-5
)
 
# Register environment
register_env(env_name, env_config)

# %%
print(np.__version__)
# Out:
# 1.23.1

# %%
import numpy as np
np.bool = np.bool_
from tqdm import tqdm
# Initialize Ray and Build Agent
ray.init(ignore_reinit_error=True)
agent = PPOTrainer(env=env_name,
    config=rl_config)
 
results = []
for i in tqdm(range(500)):
    res = agent.train()
    results.append(res)
    if (i+1) % 5 == 0:
        print('\rIter: {}\tReward: {:.2f}'.format(
                i+1, res['episode_reward_mean']), end='')
ray.shutdown()
# Out:
# 2024-05-20 11:20:06,085	INFO worker.py:973 -- Calling ray.init() again after it has already been called.
# 2024-05-20 11:20:10,418	WARNING util.py:65 -- Install gputil for GPU system monitoring.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 10
#       8 results = []
#       9 for i in range(500):
# ---> 10     res = agent.train()
#      11     results.append(res)
#      12     if (i+1) % 5 == 0:
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/tune/trainable.py:360, in Trainable.train(self)
#     358     self._warmup_time = time.time() - self._start_time
#     359 start = time.time()
# --> 360 result = self.step()
#     361 assert isinstance(result, dict), "step() needs to return a dict."
#     363 # We do not modify internal state nor update this result if duplicate.
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/rllib/agents/trainer.py:1112, in Trainer.step(self)
#    1109 while not step_ctx.should_stop(step_attempt_results):
#    1110     # Try to train one step.
#    1111     try:
# -> 1112         step_attempt_results = self.step_attempt()
#    1113     # @ray.remote RolloutWorker failure.
#    1114     except RayError as e:
#    1115         # Try to recover w/o the failed worker.
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/rllib/agents/trainer.py:1214, in Trainer.step_attempt(self)
#    1212 # No evaluation necessary, just run the next training iteration.
#    1213 if not evaluate_this_iter:
# -> 1214     step_results = self._exec_plan_or_training_iteration_fn()
#    1215 # We have to evaluate in this training iteration.
#    1216 else:
#    1217     # No parallelism.
#    1218     if not self.config["evaluation_parallel_to_training"]:
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/rllib/agents/trainer.py:2209, in Trainer._exec_plan_or_training_iteration_fn(self)
#    2207 with self._timers[TRAINING_ITERATION_TIMER]:
#    2208     if self.config["_disable_execution_plan_api"]:
# -> 2209         results = self.training_iteration()
#    2210     else:
#    2211         results = next(self.train_exec_impl)
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/rllib/agents/ppo/ppo.py:450, in PPOTrainer.training_iteration(self)
#     448     train_results = train_one_step(self, train_batch)
#     449 else:
# --> 450     train_results = multi_gpu_train_one_step(self, train_batch)
#     452 global_vars = {
#     453     "timestep": self._counters[NUM_AGENT_STEPS_SAMPLED],
#     454 }
#     456 # Update weights - after learning on the local worker - on all remote
#     457 # workers.
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/rllib/execution/train_ops.py:167, in multi_gpu_train_one_step(trainer, train_batch)
#     162         permutation = np.random.permutation(num_batches)
#     163         for batch_index in range(num_batches):
#     164             # Learn on the pre-loaded data in the buffer.
#     165             # Note: For minibatch SGD, the data is an offset into
#     166             # the pre-loaded entire train batch.
# --> 167             results = policy.learn_on_loaded_batch(
#     168                 permutation[batch_index] * per_device_batch_size, buffer_index=0
#     169             )
#     171             learner_info_builder.add_learn_on_batch_results(results, policy_id)
#     173 # Tower reduce and finalize results.
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/rllib/policy/torch_policy.py:579, in TorchPolicy.learn_on_loaded_batch(self, offset, buffer_index)
#     577     else:
#     578         batch = self._loaded_batches[0][0][offset : offset + device_batch_size]
# --> 579     return self.learn_on_batch(batch)
#     581 if len(self.devices) > 1:
#     582     # Copy weights of main model (tower-0) to all other towers.
#     583     state_dict = self.model.state_dict()
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/rllib/utils/threading.py:21, in with_lock.<locals>.wrapper(self, *a, **k)
#      19 try:
#      20     with self._lock:
# ---> 21         return func(self, *a, **k)
#      22 except AttributeError as e:
#      23     if "has no attribute '_lock'" in e.args[0]:
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/rllib/policy/torch_policy.py:477, in TorchPolicy.learn_on_batch(self, postprocessed_batch)
#     471 self.callbacks.on_learn_on_batch(
#     472     policy=self, train_batch=postprocessed_batch, result=learn_stats
#     473 )
#     475 # Compute gradients (will calculate all losses and `backward()`
#     476 # them to get the grads).
# --> 477 grads, fetches = self.compute_gradients(postprocessed_batch)
#     479 # Step the optimizers.
#     480 self.apply_gradients(_directStepOptimizerSingleton)
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/rllib/utils/threading.py:21, in with_lock.<locals>.wrapper(self, *a, **k)
#      19 try:
#      20     with self._lock:
# ---> 21         return func(self, *a, **k)
#      22 except AttributeError as e:
#      23     if "has no attribute '_lock'" in e.args[0]:
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/rllib/policy/torch_policy.py:660, in TorchPolicy.compute_gradients(self, postprocessed_batch)
#     657 self._lazy_tensor_dict(postprocessed_batch, device=self.devices[0])
#     659 # Do the (maybe parallelized) gradient calculation step.
# --> 660 tower_outputs = self._multi_gpu_parallel_grad_calc([postprocessed_batch])
#     662 all_grads, grad_info = tower_outputs[0]
#     664 grad_info["allreduce_latency"] /= len(self._optimizers)
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/rllib/policy/torch_policy.py:1156, in TorchPolicy._multi_gpu_parallel_grad_calc(self, sample_batches)
#    1152 if len(self.devices) == 1 or self.config["_fake_gpus"]:
#    1153     for shard_idx, (model, sample_batch, device) in enumerate(
#    1154         zip(self.model_gpu_towers, sample_batches, self.devices)
#    1155     ):
# -> 1156         _worker(shard_idx, model, sample_batch, device)
#    1157         # Raise errors right away for better debugging.
#    1158         last_result = results[len(results) - 1]
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/rllib/policy/torch_policy.py:1076, in TorchPolicy._multi_gpu_parallel_grad_calc.<locals>._worker(shard_idx, model, sample_batch, device)
#    1071 try:
#    1072     with NullContextManager() if device.type == "cpu" else torch.cuda.device(  # noqa: E501
#    1073         device
#    1074     ):
#    1075         loss_out = force_list(
# -> 1076             self._loss(self, model, self.dist_class, sample_batch)
#    1077         )
#    1079         # Call Model's custom-loss with Policy loss outputs and
#    1080         # train_batch.
#    1081         loss_out = model.custom_loss(loss_out, sample_batch)
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/rllib/agents/ppo/ppo_torch_policy.py:128, in PPOTorchPolicy.loss(self, model, dist_class, train_batch)
#     126 # Only calculate kl loss if necessary (kl-coeff > 0.0).
#     127 if self.config["kl_coeff"] > 0.0:
# --> 128     action_kl = prev_action_dist.kl(curr_action_dist)
#     129     mean_kl_loss = reduce_mean_valid(action_kl)
#     130 else:
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/rllib/models/torch/torch_action_dist.py:160, in TorchMultiCategorical.kl(self, other)
#     158 @override(TorchDistributionWrapper)
#     159 def kl(self, other: ActionDistribution) -> TensorType:
# --> 160     return torch.sum(self.multi_kl(other), dim=1)
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/rllib/models/torch/torch_action_dist.py:151, in TorchMultiCategorical.multi_kl(self, other)
#     148 @override(ActionDistribution)
#     149 def multi_kl(self, other: ActionDistribution) -> TensorType:
#     150     return torch.stack(
# --> 151         [
#     152             torch.distributions.kl.kl_divergence(cat, oth_cat)
#     153             for cat, oth_cat in zip(self.cats, other.cats)
#     154         ],
#     155         dim=1,
#     156     )
#
# File ~/anaconda3/envs/api/lib/python3.10/site-packages/ray/rllib/models/torch/torch_action_dist.py:152, in <listcomp>(.0)
#     148 @override(ActionDistribution)
#     149 def multi_kl(self, other: ActionDistribution) -> TensorType:
#     150     return torch.stack(
#     151         [
# --> 152             torch.distributions.kl.kl_divergence(cat, oth_cat)
#     153             for cat, oth_cat in zip(self.cats, other.cats)
#     154         ],
#     155         dim=1,
#     156     )
#
# File ~/.local/lib/python3.10/site-packages/torch/distributions/kl.py:172, in kl_divergence(p, q)
#     169 if fun is NotImplemented:
#     170     raise NotImplementedError("No KL(p || q) is implemented for p type {} and q type {}"
#     171                               .format(p.__class__.__name__, q.__class__.__name__))
# --> 172 return fun(p, q)
#
# File ~/.local/lib/python3.10/site-packages/torch/distributions/kl.py:221, in _kl_categorical_categorical(p, q)
#     219 t = p.probs * (p.logits - q.logits)
#     220 t[(q.probs == 0).expand_as(t)] = inf
# --> 221 t[(p.probs == 0).expand_as(t)] = 0
#     222 return t.sum(-1)
#
# KeyboardInterrupt:

# %%
# Unpack values from each iteration
rewards = np.hstack([i['hist_stats']['episode_reward'] 
    for i in results])
pol_loss = [
    i['info']['learner']['default_policy']['policy_loss'] 
    for i in results]
vf_loss = [
    i['info']['learner']['default_policy']['vf_loss'] 
    for i in results]
p = 100
mean_rewards = np.array([np.mean(rewards[i-p:i+1]) 
                if i >= p else np.mean(rewards[:i+1]) 
                for i, _ in enumerate(rewards)])
std_rewards = np.array([np.std(rewards[i-p:i+1])
               if i >= p else np.std(rewards[:i+1])
               for i, _ in enumerate(rewards)])
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
gs = fig.add_gridspec(2, 4)
ax0 = fig.add_subplot(gs[:, :-2])
ax0.fill_between(np.arange(len(mean_rewards)), 
                 mean_rewards - std_rewards, 
                 mean_rewards + std_rewards, 
                 label='Standard Deviation', alpha=0.3)
ax0.plot(mean_rewards, label='Mean Rewards')
ax0.set_ylabel('Rewards')
ax0.set_xlabel('Episode')
ax0.set_title('Training Rewards')
ax0.legend()
ax1 = fig.add_subplot(gs[0, 2:])
ax1.plot(pol_loss)
ax1.set_ylabel('Loss')
ax1.set_xlabel('Iteration')
ax1.set_title('Policy Loss')
ax2 = fig.add_subplot(gs[1, 2:])
ax2.plot(vf_loss)
ax2.set_ylabel('Loss')
ax2.set_xlabel('Iteration')
ax2.set_title('Value Function Loss')
plt.show()
# Out:
# Box(3,)

# %% [markdown]
# # Derivative Free Optimization

# %%
from scipy.optimize import minimize
import or_gym
import numpy as np
env_name = 'InvManagement-v1'
# env_name = "Knapsack-v0"
env_config = {} # Change environment parameters here
#TODO: Change the environment name to the one you want to use by random generation

# %%
def base_stock_policy(policy, env):
  '''
  Implements a re-order up-to policy. This means that for
  each node in the network, if the inventory at that node 
  falls below the level denoted by the policy, we will 
  re-order inventory to bring it to the policy level.
  
  For example, policy at a node is 10, current inventory
  is 5: the action is to order 5 units.
  '''
  assert len(policy) == len(env.init_inv), (
    'Policy should match number of nodes in network' + 
    '({}, {}).'.format(len(policy), len(env.init_inv)))
  
  # Get echelon inventory levels
  if env.period == 0:
    inv_ech = np.cumsum(env.I[env.period] +
      env.T[env.period])
  else:
    inv_ech = np.cumsum(env.I[env.period] +
      env.T[env.period] - env.B[env.period-1, :-1])
      
  # Get unconstrained actions
  unc_actions = policy - inv_ech
  unc_actions = np.where(unc_actions>0, unc_actions, 0)
  
  # Ensure that actions can be fulfilled by checking 
  # constraints
  inv_const = np.hstack([env.I[env.period, 1:], np.Inf])
  actions = np.minimum(env.c, np.minimum(unc_actions, inv_const))
  return actions

def dfo_func(policy, env, *args):
    '''
    Runs an episode based on current base-stock model 
    settings. This allows us to use our environment for the 
    DFO optimizer.
    '''
    env.reset() # Ensure env is fresh
    rewards = []
    done = False
    while not done:
        action = base_stock_policy(policy, env)
        state, reward, done, _ = env.step(action)
        rewards.append(reward)
        if done:
            break
            
    rewards = np.array(rewards)
    prob = env.demand_dist.pmf(env.D, **env.dist_param)
    
    # Return negative of expected profit
    return -1 / env.num_periods * np.sum(prob * rewards)
  
def optimize_inventory_policy(env_name, fun,
  init_policy=None, env_config={}, method='Powell'):
  
  env = or_gym.make(env_name, env_config=env_config)
  
  if init_policy is None:
      init_policy = np.ones(env.num_stages-1)
      
  # Optimize policy
  out = minimize(fun=fun, x0=init_policy, args=env, 
      method=method)
  policy = out.x.copy()
  
  # Policy must be positive integer
  policy = np.round(np.maximum(policy, 0), 0).astype(int)
  
  return policy, out

# %%
policy, out = optimize_inventory_policy('InvManagement-v1',
    dfo_func)
print("Re-order levels: {}".format(policy))
print("DFO Info:\n{}".format(out))

env = or_gym.make(env_name, env_config=env_config)
eps = 1000
rewards = []
for i in range(eps):
    env.reset()
    reward = 0
    while True:
        action = base_stock_policy(policy, env)
        s, r, done, _ = env.step(action)
        reward += r
        if done:
            rewards.append(reward)
            break
# Out:
# Re-order levels: [115  10  28]
# DFO Info:
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: -0.24102348149186117
#        x: [ 1.149e+02  9.862e+00  2.838e+01]
#      nit: 3
#    direc: [[ 0.000e+00  0.000e+00  1.000e+00]
#            [ 0.000e+00  1.000e+00  0.000e+00]
#            [ 1.479e+01  8.220e-01  3.302e+00]]
#     nfev: 124

# %%
env.num_stages
# Out:
# 4
